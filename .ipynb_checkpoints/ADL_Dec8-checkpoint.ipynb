# %% [markdown]
# # The whole assignment was executed on Google Colab

# %%
from IPython.display import Image
import cv2 
import numpy as np

import matplotlib.pyplot as plt
#We want to see one of the training data with its label
# Change the folders or the code that the path points to your data
training_images = '/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train/image'
training_labels = '/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train/label'

#We use the function Image(file_name) to print the image '0.png' and the label 'o.png'
### Insert Code ###
#display(Image(training_images + '0.png'))
#display(Image(training_labels + '0.png'))
#display(Image(___))
#display(Image(___))
#file_name_img = training_images\\'0.png'
#file_name_labels= training_labels\\'0.png'
img = cv2.imread('/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train/image/0.png')
labels = cv2.imread('/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train/label/0.png')

# %%
plt.imshow(img)

# %%
plt.imshow(labels)

# %%
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os 
import glob
import skimage.io as io #pip install scikit-image pip install scipy
# if This Error occurs:
# <<ImportError: cannot import name 'rgb2gray'>>
# restart your kernel
import skimage.transform as trans
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    coef = (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
    return coef

# %%
def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def unet(pretrained_weights=None, input_size=(256, 256, 1)): #the values given for the parameters are the default values
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    # complete the missing layers (your may use copy and past plus adapting)
    
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    up8 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    up9 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    
    # In the last layer we chose the <sigmoid> as activation function because the output has to be between zero and one.
    # We normalized out pixle values by deviding through 255.
    # For our example we have only one class and thus only needing
    # zero being white (our predicted object-segment) and 1 beeing black. 
    # but if we have more that one class the different colors will also lie inbetween 0 and 1 and every
    # prediction is labeld with the appropriate number. 
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    # With the following method <Model> we define out input and output of or Neural Network
    # please complete:
    model = Model(inputs=inputs, outputs=conv10)

    # with Model.compile we configure and prepare our netwrok for training. Thus we define our optimizer for 
    # learning with it's learning rate, the loss function and the metrics.
    model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss=dice_coef_loss, metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

    # model.summary()
    
    # this part we need for resume to a training or printing test, results for an already trained network, be careful
    # that the input_size you defined for the model match with the one you defined for the model you take the pretrained
    # weights from!
    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        # normalize the image
        img = img / 255
        # normalize the mask 
        mask = mask /255
        # convert your mask vector into a one-hot vector 
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
        # mask[mask > __] = __
        # mask[] = __
    return (img,mask)

# %%
def trainGenerator(batch_size,train_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (256,256),seed = 1):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    # the generated masks and images are now passed on the function <<adjustData>> discussed beforehand
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)
        
# to understand what yield is: https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do

# %%
def testGenerator(test_path,num_image = 30,target_size = (256,256),flag_multi_class = False,as_gray = True):
    for i in range(num_image):
        img = io.imread(os.path.join(test_path,"%d.png"%i),as_gray = as_gray)
        img = img / 255
        img = trans.resize(img,target_size)
        img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        img = np.reshape(img,(1,)+img.shape)
        yield img

# %%
def labelVisualize(num_class,color_dict,img):
    img = img[:,:,0] if len(img.shape) == 3 else img
    img_out = np.zeros(img.shape + (3,))
    for i in range(num_class):
        img_out[img == i,:] = color_dict[i]
    return img_out / 255

# %%
def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)

# %%
# if it fails to run the training on your tensorflow-gpu 
# rerun it on a tensorflow cpu version

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train','image','label',data_gen_args,save_to_dir = None)

model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=5,callbacks=[model_checkpoint])

testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test",results)
# Out:
# WARNING:tensorflow:From <ipython-input-14-0e0baed2e978>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Found 31 images belonging to 1 classes.
# Found 31 images belonging to 1 classes.
# Epoch 1/5
#   2/300 [..............................] - ETA: 21s - loss: 0.6933 - accuracy: 0.4128WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0441s vs `on_train_batch_end` time: 0.0972s). Check your callbacks.
# 300/300 [==============================] - ETA: 0s - loss: 0.3739 - accuracy: 0.8121
# Epoch 00001: loss improved from inf to 0.37386, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 46s 154ms/step - loss: 0.3739 - accuracy: 0.8121
# Epoch 2/5
# 300/300 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.9026
# Epoch 00002: loss improved from 0.37386 to 0.24950, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 46s 154ms/step - loss: 0.2495 - accuracy: 0.9026
# Epoch 3/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9151
# Epoch 00003: loss improved from 0.24950 to 0.19571, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 47s 156ms/step - loss: 0.1957 - accuracy: 0.9151
# Epoch 4/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9222
# Epoch 00004: loss improved from 0.19571 to 0.17855, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 48s 158ms/step - loss: 0.1785 - accuracy: 0.9222
# Epoch 5/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9275
# Epoch 00005: loss improved from 0.17855 to 0.16548, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 48s 160ms/step - loss: 0.1655 - accuracy: 0.9275
# WARNING:tensorflow:From <ipython-input-14-0e0baed2e978>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 30/30 [==============================] - 1s 33ms/step
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test",results)
# Out:
#  1/30 [>.............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_predict_batch_end` time: 0.0392s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_predict_batch_end` time: 0.0392s). Check your callbacks.
# 30/30 [==============================] - 1s 35ms/step
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
test_images_path = "data/Unet/membrane/test/"
# number 0 to 29 your want to show
#img_number = __
from PIL import Image
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512 at 0x7FAFA36447F0>

# %%
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0_predict.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7FAF3FF71978>

# %%
# load the pretrained net within the folder
model = unet(pretrained_weights='/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/unet_membrane_pretrained.hdf5')
testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test",results)
# Out:
#  1/30 [>.............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_predict_batch_end` time: 0.0389s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_predict_batch_end` time: 0.0389s). Check your callbacks.
# 30/30 [==============================] - 1s 34ms/step
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# show results with this weights
test_path = "/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test"
# number 0 to 29 your want to show
from PIL import Image
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512 at 0x7FAFA36BCE48>

# %%
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0_predict.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7FAF3F5530F0>

# %% [markdown]
# Using zebrafish repository and dice_coefficient loss

# %%
from IPython.display import Image
import cv2 
import numpy as np

import matplotlib.pyplot as plt
#We want to see one of the training data with its label
# Change the folders or the code that the path points to your data
training_images = '/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/image/ventral_sample_gray'
training_labels = '/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/label/ventral_mask'

#We use the function Image(file_name) to print the image '0.png' and the label 'o.png'
### Insert Code ###
#display(Image(training_images + '0.png'))
#display(Image(training_labels + '0.png'))
#display(Image(___))
#display(Image(___))
#file_name_img = training_images\\'0.png'
#file_name_labels= training_labels\\'0.png'
img = cv2.imread('/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/image/ventral_sample_gray/00020.tif')
labels = cv2.imread('/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/label/ventral_mask/00020.tif')

# %%
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os 
import glob
import skimage.io as io #pip install scikit-image pip install scipy
# if This Error occurs:
# <<ImportError: cannot import name 'rgb2gray'>>
# restart your kernel
import skimage.transform as trans
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    coef = (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
    return coef

# %%
def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def unet(pretrained_weights=None, input_size=(256, 256, 1)): #the values given for the parameters are the default values
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    # complete the missing layers (your may use copy and past plus adapting)
    
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    up8 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    up9 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    
    # In the last layer we chose the <sigmoid> as activation function because the output has to be between zero and one.
    # We normalized out pixle values by deviding through 255.
    # For our example we have only one class and thus only needing
    # zero being white (our predicted object-segment) and 1 beeing black. 
    # but if we have more that one class the different colors will also lie inbetween 0 and 1 and every
    # prediction is labeld with the appropriate number. 
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    # With the following method <Model> we define out input and output of or Neural Network
    # please complete:
    model = Model(inputs=inputs, outputs=conv10)

    # with Model.compile we configure and prepare our netwrok for training. Thus we define our optimizer for 
    # learning with it's learning rate, the loss function and the metrics.
    #model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=SGD(lr=1e-4), loss=dice_coef_loss, metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

    model.summary()
    
    # this part we need for resume to a training or printing test, results for an already trained network, be careful
    # that the input_size you defined for the model match with the one you defined for the model you take the pretrained
    # weights from!
    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        # normalize the image
        img = img / 255
        # normalize the mask 
        mask = mask /255
        # convert your mask vector into a one-hot vector 
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
        # mask[mask > __] = __
        # mask[] = __
    return (img,mask)

# %%
def trainGenerator(batch_size,train_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (256,256),seed = 1):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    # the generated masks and images are now passed on the function <<adjustData>> discussed beforehand
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)
        
# to understand what yield is: https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do

# %%
def testGenerator(test_path,num_image = 30,target_size = (256,256),flag_multi_class = False,as_gray = True):
    for i in range(num_image):
        img = io.imread(os.path.join(test_path,"%05d.tif"% i),as_gray = as_gray)
        img = img / 255
        img = trans.resize(img,target_size)
        img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        img = np.reshape(img,(1,)+img.shape)
        yield img

# %%
def labelVisualize(num_class,color_dict,img):
    img = img[:,:,0] if len(img.shape) == 3 else img
    img_out = np.zeros(img.shape + (3,))
    for i in range(num_class):
        img_out[img == i,:] = color_dict[i]
    return img_out / 255

# %%
def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%5d.png"%i),img)

# %%
# if it fails to run the training on your tensorflow-gpu 
# rerun it on a tensorflow cpu version

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data','image','label',data_gen_args,save_to_dir = None)

model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=15,callbacks=[model_checkpoint])
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,031,685
# Trainable params: 31,031,685
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From <ipython-input-12-ce90e6fb7d10>:15: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Found 566 images belonging to 1 classes.
# Found 564 images belonging to 1 classes.
# Epoch 1/15
#   2/300 [..............................] - ETA: 21s - loss: 1.0000 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0408s vs `on_train_batch_end` time: 0.0996s). Check your callbacks.
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00001: loss improved from inf to 1.00000, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 660s 2s/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 2/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00002: loss did not improve from 1.00000
# 300/300 [==============================] - 44s 148ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 3/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00003: loss did not improve from 1.00000
# 300/300 [==============================] - 45s 151ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 4/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00004: loss did not improve from 1.00000
# 300/300 [==============================] - 46s 154ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 5/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00005: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 156ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 6/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00006: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 157ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 7/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00007: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 157ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 8/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00008: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 158ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 9/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00009: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 158ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 10/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00010: loss did not improve from 1.00000
# 300/300 [==============================] - 48s 158ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 11/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00011: loss did not improve from 1.00000
# 300/300 [==============================] - 48s 159ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 12/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00012: loss did not improve from 1.00000
# 300/300 [==============================] - 48s 159ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 13/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00013: loss did not improve from 1.00000
# 300/300 [==============================] - 48s 159ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 14/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00014: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 158ms/step - loss: 1.0000 - accuracy: 1.0000
# Epoch 15/15
# 300/300 [==============================] - ETA: 0s - loss: 1.0000 - accuracy: 1.0000
# Epoch 00015: loss did not improve from 1.00000
# 300/300 [==============================] - 47s 158ms/step - loss: 1.0000 - accuracy: 1.0000

# %%
# !pip install imagecodecs
# !pip install tifffile
# Out:
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.6/dist-packages (2020.5.30)
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.6/dist-packages (from imagecodecs) (1.18.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.6/dist-packages (2020.9.3)
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.6/dist-packages (from tifffile) (1.18.5)

# %%
import imagecodecs
testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/ventral_sample_gray")
results = model.predict_generator(testGene,10,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test",results)
# Out:
# WARNING:tensorflow:From <ipython-input-14-e0f1801aa460>:3: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 10/10 [==============================] - 0s 31ms/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    0.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    1.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    2.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    3.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    4.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    5.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    6.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    7.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    8.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    9.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
test_images_path = "/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test"
# number 0 to 29 your want to show
from PIL import Image
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/ventral_sample_gray/00002.tif")
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=640x480 at 0x7F8A21341940>

# %%
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test/    2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F89BC1354E0>

# %% [markdown]
# Number of epochs trained is not sufficient.

# %% [markdown]
# **Car** dataset : CARLA simulator, using ADAM optimizer

# %%
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os 
import glob
import skimage.io as io #pip install scikit-image pip install scipy
# if This Error occurs:
# <<ImportError: cannot import name 'rgb2gray'>>
# restart your kernel
import skimage.transform as trans
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    coef = (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
    return coef

# %%
def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def unet(pretrained_weights=None, input_size=(256, 256, 1)): #the values given for the parameters are the default values
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    # complete the missing layers (your may use copy and past plus adapting)
    
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    up8 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    up9 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    
    # In the last layer we chose the <sigmoid> as activation function because the output has to be between zero and one.
    # We normalized out pixle values by deviding through 255.
    # For our example we have only one class and thus only needing
    # zero being white (our predicted object-segment) and 1 beeing black. 
    # but if we have more that one class the different colors will also lie inbetween 0 and 1 and every
    # prediction is labeld with the appropriate number. 
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    # With the following method <Model> we define out input and output of or Neural Network
    # please complete:
    model = Model(inputs=inputs, outputs=conv10)

    # with Model.compile we configure and prepare our netwrok for training. Thus we define our optimizer for 
    # learning with it's learning rate, the loss function and the metrics.
    model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss=dice_coef_loss, metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

    # model.summary()
    
    # this part we need for resume to a training or printing test, results for an already trained network, be careful
    # that the input_size you defined for the model match with the one you defined for the model you take the pretrained
    # weights from!
    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        # normalize the image
        img = img / 255
        # normalize the mask 
        mask = mask /255
        # convert your mask vector into a one-hot vector 
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
        # mask[mask > __] = __
        # mask[] = __
    return (img,mask)

# %%
def trainGenerator(batch_size,train_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (256,256),seed = 1):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    # the generated masks and images are now passed on the function <<adjustData>> discussed beforehand
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)
        
# to understand what yield is: https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do

# %%
def testGenerator(test_path,num_image = 30,target_size = (256,256),flag_multi_class = False,as_gray = True):
    for i in range(num_image):
        img = io.imread(os.path.join(test_path,"%04d.png"%i),as_gray = as_gray)
        img = img / 255
        img = trans.resize(img,target_size)
        img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        img = np.reshape(img,(1,)+img.shape)
        yield img

# %%
def labelVisualize(num_class,color_dict,img):
    img = img[:,:,0] if len(img.shape) == 3 else img
    img_out = np.zeros(img.shape + (3,))
    for i in range(num_class):
        img_out[img == i,:] = color_dict[i]
    return img_out / 255

# %%
def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%05d.png"%i),img)

# %%
# if it fails to run the training on your tensorflow-gpu 
# rerun it on a tensorflow cpu version

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A','CameraRGB','CameraSeg',data_gen_args,save_to_dir = None)

model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=5,callbacks=[model_checkpoint])
# Out:
# Found 1000 images belonging to 1 classes.
# Found 1000 images belonging to 1 classes.
# Epoch 1/5
#   2/300 [..............................] - ETA: 45s - loss: 0.7321 - accuracy: 0.0109WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0576s vs `on_train_batch_end` time: 0.0955s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0576s vs `on_train_batch_end` time: 0.0955s). Check your callbacks.
# 300/300 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.6508
# Epoch 00001: loss improved from inf to 0.69586, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 227s 757ms/step - loss: 0.6959 - accuracy: 0.6508
# Epoch 2/5
# 300/300 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.9716
# Epoch 00002: loss improved from 0.69586 to 0.68272, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 788s 3s/step - loss: 0.6827 - accuracy: 0.9716
# Epoch 3/5
# 300/300 [==============================] - ETA: 0s - loss: 0.6746 - accuracy: 0.9971
# Epoch 00003: loss improved from 0.68272 to 0.67461, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 45s 151ms/step - loss: 0.6746 - accuracy: 0.9971
# Epoch 4/5
# 300/300 [==============================] - ETA: 0s - loss: 0.6664 - accuracy: 0.9996
# Epoch 00004: loss improved from 0.67461 to 0.66636, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 46s 154ms/step - loss: 0.6664 - accuracy: 0.9996
# Epoch 5/5
# 300/300 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.9999
# Epoch 00005: loss improved from 0.66636 to 0.65721, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 47s 156ms/step - loss: 0.6572 - accuracy: 0.9999

# %%
testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/test")
results = model.predict_generator(testGene,15,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test",results)
# Out:
# 15/15 [==============================] - 28s 2s/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00000.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00001.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00002.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00003.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00004.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00005.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00006.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00007.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00008.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00009.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00010.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00011.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00012.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00013.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: /content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/00014.png is a low contrast image
#   after removing the cwd from sys.path.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
test_images_path = "/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data2/data/test_images/Test"
# number 0 to 29 your want to show
from PIL import Image
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/test/0000.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x600 at 0x7FAF3E14B5C0>

# %%
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test/    0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7FAF3E14B438>

# %% [markdown]
# Inference:The model should have been tested with more epochs for better results.

# %% [markdown]
# Model tested with ADAM optimizer and dice-coefficient loss.
# Dataset:Membrane

# %%
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os 
import glob
import skimage.io as io #pip install scikit-image pip install scipy
# if This Error occurs:
# <<ImportError: cannot import name 'rgb2gray'>>
# restart your kernel
import skimage.transform as trans
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    coef = (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
    return coef

# %%
def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def unet(pretrained_weights=None, input_size=(256, 256, 1)): #the values given for the parameters are the default values
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    # complete the missing layers (your may use copy and past plus adapting)
    
    conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    up8 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    up9 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    
    # In the last layer we chose the <sigmoid> as activation function because the output has to be between zero and one.
    # We normalized out pixle values by deviding through 255.
    # For our example we have only one class and thus only needing
    # zero being white (our predicted object-segment) and 1 beeing black. 
    # but if we have more that one class the different colors will also lie inbetween 0 and 1 and every
    # prediction is labeld with the appropriate number. 
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    # With the following method <Model> we define out input and output of or Neural Network
    # please complete:
    model = Model(inputs=inputs, outputs=conv10)

    # with Model.compile we configure and prepare our netwrok for training. Thus we define our optimizer for 
    # learning with it's learning rate, the loss function and the metrics.
    #model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=SGD(lr=1e-4), loss=dice_coef_loss, metrics=['accuracy'])
    #model.compile(optimizer=SGD(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

    # model.summary()
    
    # this part we need for resume to a training or printing test, results for an already trained network, be careful
    # that the input_size you defined for the model match with the one you defined for the model you take the pretrained
    # weights from!
    if (pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        # normalize the image
        img = img / 255
        # normalize the mask 
        mask = mask /255
        # convert your mask vector into a one-hot vector 
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
        # mask[mask > __] = __
        # mask[] = __
    return (img,mask)

# %%
def trainGenerator(batch_size,train_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (256,256),seed = 1):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    # the generated masks and images are now passed on the function <<adjustData>> discussed beforehand
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)
        
# to understand what yield is: https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do

# %%
def testGenerator(test_path,num_image = 30,target_size = (256,256),flag_multi_class = False,as_gray = True):
    for i in range(num_image):
        img = io.imread(os.path.join(test_path,"%d.png"%i),as_gray = as_gray)
        img = img / 255
        img = trans.resize(img,target_size)
        img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        img = np.reshape(img,(1,)+img.shape)
        yield img

# %%
def labelVisualize(num_class,color_dict,img):
    img = img[:,:,0] if len(img.shape) == 3 else img
    img_out = np.zeros(img.shape + (3,))
    for i in range(num_class):
        img_out[img == i,:] = color_dict[i]
    return img_out / 255

# %%
def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)

# %%
# if it fails to run the training on your tensorflow-gpu 
# rerun it on a tensorflow cpu version

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/train','image','label',data_gen_args,save_to_dir = None)

model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=5,callbacks=[model_checkpoint])
# Out:
# Found 31 images belonging to 1 classes.
# Found 31 images belonging to 1 classes.
# Epoch 1/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.7812
# Epoch 00001: loss improved from inf to 0.17635, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 44s 148ms/step - loss: 0.1764 - accuracy: 0.7812
# Epoch 2/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.7813
# Epoch 00002: loss improved from 0.17635 to 0.13547, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 45s 148ms/step - loss: 0.1355 - accuracy: 0.7813
# Epoch 3/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.7814
# Epoch 00003: loss improved from 0.13547 to 0.12990, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 45s 151ms/step - loss: 0.1299 - accuracy: 0.7814
# Epoch 4/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.7815
# Epoch 00004: loss improved from 0.12990 to 0.12795, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 46s 153ms/step - loss: 0.1279 - accuracy: 0.7815
# Epoch 5/5
# 300/300 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.7815
# Epoch 00005: loss improved from 0.12795 to 0.12696, saving model to unet_membrane.hdf5
# 300/300 [==============================] - 46s 154ms/step - loss: 0.1270 - accuracy: 0.7815

# %%
testGene = testGenerator("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/carla-capture-20180513A/Test",results)
# Out:
#  1/30 [>.............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0033s vs `on_predict_batch_end` time: 0.0382s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0033s vs `on_predict_batch_end` time: 0.0382s). Check your callbacks.
# 30/30 [==============================] - 1s 34ms/step
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
test_images_path = "data/Unet/membrane/test/"
# number 0 to 29 your want to show
#img_number = __
from PIL import Image
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512 at 0x7F87ADED6A20>

# %%
Image.open("/content/drive/MyDrive/Work/DL/ADL_05_Tutorial_Schutera/data/Unet/membrane/test/0_predict.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F87ADED6BE0>

# %% [markdown]
# **We will add an Dropout after convolution 4 and 5, please explain what could be the purpose to add those two layers?**
# The dropout is added :
# 1. To try to reduce the full relation of neurons between each other, so that the model becomes overfitted.
# 2. To eliminate the neurons dying, since during backpropagation, the weights of the neurons might be so small, and might not be activated.

# %% [markdown]
# d.

# %% [markdown]
# **Which initialization do you think is beneficial?**
# RandomNormal initialization is the optimal solution so that the weights initialized are not biased.

# %% [markdown]
# Loss function:
#
# mean squared error:
# (squared) hinge:
# crossentropy:
# dice-loss
# poisson:
# Optimizers:
#
# Stochastic Gradient Descent:
# RMSprop:
# Adagrad:
# Adam Optimizer:

# %% [markdown]
# Why it is advised to add an epsilon to your denominator?

# %% [markdown]
# In order to eliminate zero , in the denominator, when the weights are initialised first.
